# %% [markdown]
# ## Project Title - Global Superstore Business Analytics

# %% [markdown]
# ## Business Background
#
# ### What is this company? --> Superstore Business Market
# ### What does it sell? --> they sell in various types of products with sub-categories like Furniture, Office Supllie, Technology relevant products
# ### What kind of data do we have? --> Retail store data which contains numerial, categorical, text, date etc.

# %% [markdown]
# ## 3. Business Problem (when they hire as a data analyst)
# ### 1. They wants to understands customer behavior.
# ### 2. They wants to inprove sales.
# ### 3. They need to make business decisions.

# %% [markdown]
# ## 4. Stakeholders --> Regional Manager

# %% [markdown]
# ## 5. Project Objective --
# ### 1. Analyze sales perfornace.
# ### 2. Identify top-performing products.
# ### 3. Growth rate from evry region.
# ### 4. Indentifying root cause of dropping sales.

# %% [markdown]
# ## 6. Business Problems
#
# ### 1. which 20% of product are gaining 80% revenue ?
# ### 2. what is the gaps is in between first and later purchacing products?
# ### 3. which product is gaining most profit/ sell?
# ### 4. which category's product creates best sales in same category?
# ### 5. which sub-category's product creates best sales in same sub-category?
# ### 6. which product performing lower than others?
# ### 7. which customer is purchacing most of products?
# ### 8. which segment's performing best than other?
# ### 9. which shiping mode is mostly prefreble by the customers?
# ### 10. which product is performing best in city wise?
# ### 11. which product performing worst in city wise?
# ### 12. which product is performing best in state wise?
# ### 13. which product performing worst in state wise?
# ### 14. which product performing worst in region wise?
# ### 15. which product performing best in region wise?
# ### 16. whcih day most of the products are selling?
# ### 17. which day(datewise) product are performing worst in sales?
# ### 18. which product performes best month wise?
# ### 19. which product performs worst months wise?
# ### 20. which product mostly liked by the custmores?
# ###

# %% [markdown]
# ## 7. Expected Outcome
# ###  1. best selling products.
# ###  2. customer trends.
# ###  3. best sales by regions.
